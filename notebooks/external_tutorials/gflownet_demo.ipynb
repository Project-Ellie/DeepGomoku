# %%
from gflownet_tutorial.gfn import GFNAgent

# %%
agent = GFNAgent(epochs=200)

# %% [markdown]
# First, let's take a look at the environment. The default is a 2D 8x8 grid with high reward in the corners.

# %%
agent.env.plot_reward_2d()

# %% [markdown]
# We can also look at the model structure. Notice that in this implementation, the learned parameter `z0` is separate from the neural net, and that the neural net has two output "heads": `foward_policy` and `backward_policy`.

# %%
agent.model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input (InputLayer)             [(None, 2, 8)]       0           []
#
#  flatten_1 (Flatten)            (None, 16)           0           ['input[0][0]']
#
#  dense_1 (Dense)                (None, 32)           544         ['flatten_1[0][0]']
#
#  dense_2 (Dense)                (None, 32)           1056        ['dense_1[0][0]']
#
#  forward_policy (Dense)         (None, 3)            99          ['dense_2[0][0]']
#
#  backward_policy (Dense)        (None, 2)            66          ['dense_2[0][0]']
#
# ==================================================================================================
# Total params: 1,765
# Trainable params: 1,765
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
agent.z0
# Out:
# <tf.Variable 'z0:0' shape=() dtype=float32, numpy=0.0>

# %% [markdown]
# For this demonstration, we'll just show that the GFlowNet can learn a policy that generates trajectories proportional to the reward. To do that, we'll first sample a large training set using the untrained, random policy.

# %%
agent.sample(5000)
agent.plot_sampled_data_2d()
# Out:
# 157/157 [==============================] - 0s 1ms/step
# 157/157 [==============================] - 0s 1ms/step
# 157/157 [==============================] - 0s 1ms/step
# 157/157 [==============================] - 0s 1ms/step
# 157/157 [==============================] - 0s 980us/step
# 157/157 [==============================] - 0s 1ms/step
# 157/157 [==============================] - 0s 1ms/step
# 157/157 [==============================] - 0s 998us/step
# 157/157 [==============================] - 0s 1ms/step
# 157/157 [==============================] - 0s 1ms/step
# 157/157 [==============================] - 0s 961us/step
# 157/157 [==============================] - 0s 1ms/step
# 157/157 [==============================] - 0s 996us/step
# 157/157 [==============================] - 0s 1ms/step
# 157/157 [==============================] - 0s 934us/step

# %%
u_modes, u_positions = agent.count_modes()
print(f'There are {u_modes} unique modes and {u_positions} unique positions in the training data.')
# Out:
# There are 4 unique modes and 61 unique positions in the training data.

# %% [markdown]
# Before training, the policy is uniform. The likelihood of transitioning vertically or laterally (arrows) or terminating (red octogon) is essentially uniform at every point.
#
# The probability of terminating at each position is plotted below, and we can see that without training, it looks nothing like the reward environment we plotted above. The termination probabilities are large enough, that any trajectory is unlikely to leave the origin (bottom left).

# %%
agent.plot_policy_2d()
# Out:
# 2/2 [==============================] - 0s 3ms/step

# %%
l1_error_before = agent.compare_env_to_model_policy()
# Out:
# 63/63 [==============================] - 0s 1ms/step
# 63/63 [==============================] - 0s 1ms/step
# 63/63 [==============================] - 0s 1ms/step
# 63/63 [==============================] - 0s 1ms/step
# 63/63 [==============================] - 0s 943us/step
# 63/63 [==============================] - 0s 1ms/step
# 63/63 [==============================] - 0s 1ms/step
# 63/63 [==============================] - 0s 962us/step
# 63/63 [==============================] - 0s 997us/step
# 63/63 [==============================] - 0s 1ms/step
# 63/63 [==============================] - 0s 1ms/step
# 63/63 [==============================] - 0s 1ms/step
# 63/63 [==============================] - 0s 1ms/step
# 63/63 [==============================] - 0s 1ms/step
# 63/63 [==============================] - 0s 1ms/step

# %% [markdown]
# Let's train it and see if we can do better!

# %%
agent.train()
# Out:
# Start training...
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [11], in <cell line: 1>()
# ----> 1 agent.train()
#
# File ~/.local/share/virtualenvs/DeepGomoku-yQC4gx5q/lib/python3.8/site-packages/tensorflow/python/util/traceback_utils.py:153, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
# --> 153   raise e.with_traceback(filtered_tb) from None
#     154 finally:
#     155   del filtered_tb
#
# File /tmp/__autograph_generated_filegmyc80d_.py:102, in outer_factory.<locals>.inner_factory.<locals>.tf__train(self, verbose)
#     100 epoch = ag__.Undefined('epoch')
#     101 losses = ag__.Undefined('losses')
# --> 102 ag__.for_stmt(ag__.converted_call(ag__.ld(range), (ag__.ld(self).epochs,), None, fscope), None, loop_body_2, get_state_5, set_state_5, ('best_epoch_loss',), {'iterate_names': 'epoch'})
#     103 ag__.converted_call(ag__.ld(self).model.load_weights, (ag__.ld(model_weights_path),), None, fscope)
#
# File /tmp/__autograph_generated_filegmyc80d_.py:62, in outer_factory.<locals>.inner_factory.<locals>.tf__train.<locals>.loop_body_2(itr_2)
#      60     ag__.for_stmt(ag__.ld(loss_values), None, loop_body, get_state_1, set_state_1, (), {'iterate_names': 'sample'})
#      61     ag__.converted_call(ag__.ld(epoch_loss_avg), (ag__.converted_call(ag__.ld(np).mean, (ag__.ld(losses),), None, fscope),), None, fscope)
# ---> 62 ag__.for_stmt(ag__.ld(sampler), None, loop_body_1, get_state_2, set_state_2, (), {'iterate_names': 'batch'})
#      64 def get_state_3():
#      65     return (best_epoch_loss,)
#
# File /tmp/__autograph_generated_filegmyc80d_.py:47, in outer_factory.<locals>.inner_factory.<locals>.tf__train.<locals>.loop_body_2.<locals>.loop_body_1(itr_1)
#      45 def loop_body_1(itr_1):
#      46     batch = itr_1
# ---> 47     (loss_values, gradients) = ag__.converted_call(ag__.ld(self).grad, (ag__.ld(batch),), None, fscope)
#      48     ag__.converted_call(ag__.ld(self).optimizer.apply_gradients, (ag__.converted_call(ag__.ld(zip), (ag__.ld(gradients), (ag__.ld(self).model.trainable_variables + [ag__.ld(self).z0])), None, fscope),), None, fscope)
#      49     losses = []
#
# File /tmp/__autograph_generated_file2ieoag15.py:12, in outer_factory.<locals>.inner_factory.<locals>.tf__grad(self, batch)
#      10 retval_ = ag__.UndefinedReturnValue()
#      11 with ag__.ld(tf).GradientTape() as tape:
# ---> 12     loss = ag__.converted_call(ag__.ld(self).trajectory_balance_loss, (ag__.ld(batch),), None, fscope)
#      13     grads = ag__.converted_call(ag__.ld(tape).gradient, (ag__.ld(loss), (ag__.ld(self).model.trainable_variables + [ag__.ld(self).z0])), None, fscope)
#      14 try:
#
# File /tmp/__autograph_generated_filedda2tonn.py:64, in outer_factory.<locals>.inner_factory.<locals>.tf__trajectory_balance_loss(self, batch)
#      62 fwrd_edges = ag__.Undefined('fwrd_edges')
#      63 back_policy = ag__.Undefined('back_policy')
# ---> 64 ag__.for_stmt(ag__.converted_call(ag__.ld(enumerate), (ag__.ld(positions),), None, fscope), None, loop_body, get_state, set_state, (), {'iterate_names': '(i, position)'})
#      65 try:
#      66     do_return = True
#
# File /tmp/__autograph_generated_filedda2tonn.py:23, in outer_factory.<locals>.inner_factory.<locals>.tf__trajectory_balance_loss.<locals>.loop_body(itr)
#      21 (i, position) = itr
#      22 reward = ag__.ld(rewards)[ag__.ld(i)]
# ---> 23 (trajectory, back_actions) = ag__.converted_call(ag__.ld(self).back_sample_trajectory, (ag__.ld(position),), None, fscope)
#      24 tf_traj = ag__.converted_call(ag__.ld(tf).convert_to_tensor, (ag__.ld(trajectory)[:, ...],), dict(dtype='float32'), fscope)
#      25 (forward_policy, back_policy) = ag__.converted_call(ag__.ld(self).model, (ag__.ld(tf_traj),), None, fscope)
#
# File /tmp/__autograph_generated_filein56o7te.py:14, in outer_factory.<locals>.inner_factory.<locals>.tf__back_sample_trajectory(self, position)
#      12 one_hot_position = ag__.converted_call(ag__.ld(tf).one_hot, (ag__.converted_call(ag__.ld(np).expand_dims, (ag__.ld(position), 0), None, fscope), ag__.ld(self).env_len), dict(axis=(- 1)), fscope)
#      13 positions = [ag__.ld(one_hot_position)]
# ---> 14 actions = [ag__.converted_call(ag__.converted_call(ag__.ld(tf).one_hot, ((ag__.ld(self).action_space - 1), ag__.ld(self).action_space), None, fscope).numpy, (), None, fscope)]
#      15 still_tracing = True
#      17 def get_state():
#
# AttributeError: in user code:
#
#     File "/home/wgiersche/workspace/Project-Ellie/DeepGomoku/gflownet_tutorial/gfn.py", line 394, in train  *
#         loss_values, gradients = self.grad(batch)
#     File "/home/wgiersche/workspace/Project-Ellie/DeepGomoku/gflownet_tutorial/gfn.py", line 371, in grad  *
#         loss = self.trajectory_balance_loss(batch)
#     File "/home/wgiersche/workspace/Project-Ellie/DeepGomoku/gflownet_tutorial/gfn.py", line 315, in trajectory_balance_loss  *
#         trajectory, back_actions = self.back_sample_trajectory(position)
#     File "/home/wgiersche/workspace/Project-Ellie/DeepGomoku/gflownet_tutorial/gfn.py", line 192, in back_sample_trajectory  *
#         actions = [tf.one_hot(self.action_space - 1, self.action_space).numpy()]
#
#     AttributeError: 'Tensor' object has no attribute 'numpy'

# %% [markdown]
# Let's plot the trained policy and sample from it to get a probability distribution over the environment:

# %%
agent.plot_policy_2d()
# Out:
# 2/2 [==============================] - 0s 2ms/step

# %%
l1_error_after = agent.compare_env_to_model_policy()
# Out:
# 63/63 [==============================] - 0s 663us/step
# 63/63 [==============================] - 0s 661us/step
# 63/63 [==============================] - 0s 606us/step
# 63/63 [==============================] - 0s 645us/step
# 63/63 [==============================] - 0s 661us/step
# 63/63 [==============================] - 0s 682us/step
# 63/63 [==============================] - 0s 716us/step
# 63/63 [==============================] - 0s 630us/step
# 63/63 [==============================] - 0s 666us/step
# 63/63 [==============================] - 0s 654us/step
# 63/63 [==============================] - 0s 678us/step
# 63/63 [==============================] - 0s 624us/step
# 63/63 [==============================] - 0s 614us/step
# 63/63 [==============================] - 0s 676us/step
# 63/63 [==============================] - 0s 650us/step

# %%
print(f'L1 error before {l1_error_before:.2f} and after {l1_error_after:.2f}')
# Out:
# L1 error before 1.53 and after 0.76

# %% [markdown]
# While not perfect, the model has certainly learned to generate trajectories through the environment with probability proportional to the reward! It's a far better approximation than the untrained policy, and you can imagine that it would get better with some tweaks (e.g. more training, different optimizer, etc.)
