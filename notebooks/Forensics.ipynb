# %% [markdown]
# # Forensics
#
# Here, we scrutinize inexplicable behaviour of the trained networks

# %%
from aegomoku.constants_15x15 import *
stones = [H8, I7, H9, H10, G8, I8, I10, F7, G7, I9, G5, G6, J9, J8, K7, K9, L10, I6, I5, H5, E8, H6, F6, H4, H3, G4, J7, I4, F4, J3]

# %%
from aegomoku.gomoku_board import GomokuBoard
BOARD_SIZE = 15
board = GomokuBoard(BOARD_SIZE, stones)

# %%
from aegomoku.mpl_board import MplBoard

mplb = MplBoard(BOARD_SIZE, stones=[(s.x, s.y) for s in stones], disp_width=8)

# %%
mplb.display()
