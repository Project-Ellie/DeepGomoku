# %%
from __future__ import print_function, absolute_import, division

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from wgomoku import GomokuBoard, Heuristics, GomokuTools

# %%
h = Heuristics(kappa=3.0)

# %%
b = GomokuBoard(h, 15, disp_width=8).set(5,5)
b.display()
